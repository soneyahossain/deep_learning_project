# %%
import torch
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
import torch.nn.functional as F

# %%
import torch.utils.data
import json, os
from PIL import Image, ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
import torchvision.transforms as transforms
import pandas as pd
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

class UVaBuildinglabel(torch.utils.data.Dataset):
    def __init__(self, image_path, annotation_filepath, transform = None):
        super(UVaBuildinglabel, self).__init__()
        
        print('Loading data...')
        data = pd.read_csv(annotation_filepath)              #json.load(open(annotation_filepath, 'rb'))
        
        self.transform = transforms.Compose(
        [transforms.Resize(320),  # 1. Resize smallest side to 256.
        transforms.RandomCrop(320), # 2. Crop random square of 224x224 pixels.
        #transforms.RandomHorizontalFlip(),
        transforms.ToTensor()])
        
        self.image_path = image_path    # storing image path. 
        
        
        # get the image pixel values and labels
        image_ids = data.iloc[:, 0 ]
        label_ids = data.iloc[:, 1]
        label_names = data.iloc[:, 2]

        self.image_ids = data.iloc[:, 0 ] #[img_name for (img_id, img_name) in paired_id_names]
        self.image_labels = data.iloc[:, 1]   #[img_id for (img_id, img_name) in paired_id_names]
        self.image_classes= data.iloc[:, 2]


        #print(image_ids[0])
        #print(label_ids[0])
        #print(label_names)

        
    def __getitem__(self, index):
        image_name = self.image_ids[index]
        img_ = Image.open(open(os.path.join(self.image_path, image_name), 'rb'))
        img_ = img_.convert("RGB")
        if self.transform:
            img_ = self.transform(img_)
        label_ = self.image_labels[index]
        class_name= self.image_classes[index]
        return img_, label_,image_name,class_name
    
    def __len__(self):
        return len(self.image_ids)
       
      
# You can unnormalize the transformation of torch's transforms.normalize 
# with this custom transformation.
class UnNormalize(object):
    def __init__(self, mean, std):
        self.mean = mean
        self.std = std
    def __call__(self, tensor):
        for t, m, s in zip(tensor, self.mean, self.std):
            t.mul_(s).add_(m)
        return tensor


trainset = UVaBuildinglabel('../DATA', '../DATA/DATA2trainSet.csv')
valset = UVaBuildinglabel('../DATA', '../DATA/DATA2trainSet.csv')

print("total training data",trainset.__len__())
print("total validation data",valset.__len__())
# Out:
# Loading data...
# Loading data...
# total training data 616
# total validation data 616

# %%
def train_model(net, loss_fn, batchsize, trainset, valset, optimizer, num_epochs):

    trainloader = torch.utils.data.DataLoader(trainset, batch_size=batchsize,shuffle=True, num_workers=2)
    valloader = torch.utils.data.DataLoader(valset, batch_size=batchsize,shuffle=False, num_workers=2)

    train_accuracies = []; val_accuracies = []
    train_losses = []; val_losses = []
    
    N = num_epochs
    net=net.cuda()
    loss_fn = loss_fn.cuda()

    for epoch in range(N):  # loop over the dataset multiple times
        #print(epoch)
        correct = 0.0
        running_loss = 0.0
        net.train()
        for i, data in enumerate(trainloader, 0):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels, _, _ = data

            #print(inputs.shape)
            #print(labels.shape)
            inputs = inputs.cuda()
            labels = labels.cuda()

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            #print(outputs.shape)
            #print(labels)

            loss = loss_fn(outputs, labels)
            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.item()
            max_scores, max_labels = outputs.max(1)

            #print(max_scores)
            #print(max_labels)

            correct += (max_labels == labels).sum().item()
            if (i+1) % (20) == 0:    # print every 10 mini-batches
                print('Train: [%d, %5d] loss: %.3f Accuracy: %.4f' %
                      (epoch + 1, i + 1, running_loss / i+1, correct / ((i+1)*batchsize)))
                running_loss = 0.0
        
        train_accuracies.append(correct / len(trainset))
        train_losses.append(running_loss / (i + 1))  

        net.eval()
        correct = 0
        running_loss = 0
        for i, data in enumerate(valloader, 0):
            inputs, labels, _, _ = data
            inputs = inputs.cuda()
            labels = labels.cuda()

            outputs = net(inputs)
            running_loss += loss_fn(outputs, labels).item()

            max_scores, max_labels = outputs.max(1)
            correct += (max_labels == labels).sum().item()

        print('Validation: [%d, %5d] loss: %.3f Accuracy: %.4f' % 
              (epoch + 1, i + 1, running_loss / i+1, correct / ((i+1)*batchsize)))
        
        val_accuracies.append(correct / len(valset))
        val_losses.append(running_loss / (i + 1))
            
    print('Finished Training')


    plt.figure(figsize = (10, 4))
    plt.subplot(1, 2, 1)
    plt.plot(val_losses, 'bo-', label = 'val-loss')
    plt.plot(train_losses, 'ro-', label = 'train-loss')
    plt.grid('on')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['validation', 'training'], loc='upper right')

    plt.subplot(1, 2, 2)
    plt.plot(val_accuracies, 'bo-', label = 'val-acc')
    plt.plot(train_accuracies, 'ro-', label = 'train-acc')
    plt.ylabel('accuracy')
    plt.grid('on')
    plt.xlabel('epoch')
    plt.legend(['validation', 'training'], loc='lower right')
    plt.show()

# %%
trainloader = torch.utils.data.DataLoader(trainset,shuffle=True)
no_images_per_class = torch.zeros(20)
for (i, (my_image, my_label,_,class_name)) in enumerate(trainloader):    
  no_images_per_class[my_label.item()]+=1  

print(no_images_per_class)
#weight for loss 
class_weights = 64/no_images_per_class   #as 64 is the miximum no of immage in a category
class_weights=torch.FloatTensor(class_weights)

print(class_weights)
# Out:
# tensor([19., 13., 55., 27., 64., 47., 47., 16., 20., 20., 20., 23., 39., 49.,
#         28., 24., 17., 20., 24., 44.])
# tensor([3.3684, 4.9231, 1.1636, 2.3704, 1.0000, 1.3617, 1.3617, 4.0000, 3.2000,
#         3.2000, 3.2000, 2.7826, 1.6410, 1.3061, 2.2857, 2.6667, 3.7647, 3.2000,
#         2.6667, 1.4545])

# %%
import torchvision.models as models
import torch.nn as nn
import torch.optim as optim

#weight=class_weights
loss_fn = nn.CrossEntropyLoss()
resnet = models.resnet50(pretrained = False)

#print(len(trainset.image_classes))
resnet.fc = nn.Linear(2048, 20)
optimizer = optim.SGD(resnet.parameters(), lr=5e-4, momentum=0.9)

train_model(resnet, loss_fn, 8, trainset, valset, optimizer, 30)
# Out:
# Train: [1,    20] loss: 4.337 Accuracy: 0.0813
# Train: [1,    40] loss: 2.607 Accuracy: 0.0813
# Train: [1,    60] loss: 2.048 Accuracy: 0.0979
# Validation: [1,    20] loss: 4.514 Accuracy: 0.0938
# Train: [2,    20] loss: 4.172 Accuracy: 0.1250
# Train: [2,    40] loss: 2.680 Accuracy: 0.1125
# Train: [2,    60] loss: 2.075 Accuracy: 0.1062
# Validation: [2,    20] loss: 5.694 Accuracy: 0.0938
# Train: [3,    20] loss: 4.332 Accuracy: 0.1125
# Train: [3,    40] loss: 2.537 Accuracy: 0.1187
# Train: [3,    60] loss: 2.040 Accuracy: 0.1146
# Validation: [3,    20] loss: 4.330 Accuracy: 0.1375
# Train: [4,    20] loss: 4.134 Accuracy: 0.1375
# Train: [4,    40] loss: 2.505 Accuracy: 0.1344
# Train: [4,    60] loss: 2.006 Accuracy: 0.1458
# Validation: [4,    20] loss: 3.937 Accuracy: 0.1688
# Train: [5,    20] loss: 3.949 Accuracy: 0.1562
# Train: [5,    40] loss: 2.525 Accuracy: 0.1375
# Train: [5,    60] loss: 2.000 Accuracy: 0.1250
# Validation: [5,    20] loss: 3.669 Accuracy: 0.2188
# Train: [6,    20] loss: 3.901 Accuracy: 0.1250
# Train: [6,    40] loss: 2.360 Accuracy: 0.1656
# Train: [6,    60] loss: 1.961 Accuracy: 0.1708
dataiter.next()

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', class_name)

images = images.cuda()
output = resnet(images)
_, predicted = torch.max(output, 1)

print('Predicted: ', classes[predicted.item()])
# Out:
# GroundTruth:  ('Physics Building',)
# Predicted:  Physics Building

# %%
loss_fn = nn.CrossEntropyLoss()
mobilenet = models.mobilenet_v2(pretrained=False)
mobilenet.fc = nn.Linear(2048, 20)
optimizer = optim.SGD(mobilenet.parameters(), lr=5e-4, momentum=0.9)

train_model(mobilenet, loss_fn, 8, trainset, valset, optimizer, 30)   #epoch 6 can give better results
# Out:
# Train: [1,    20] loss: 8.006 Accuracy: 0.0563
# Train: [1,    40] loss: 3.930 Accuracy: 0.0813
# Train: [1,    60] loss: 2.635 Accuracy: 0.0854
# Validation: [1,    20] loss: 6.052 Accuracy: 0.0938
# Train: [2,    20] loss: 5.217 Accuracy: 0.0750
# Train: [2,    40] loss: 2.777 Accuracy: 0.0906
# Train: [2,    60] loss: 2.150 Accuracy: 0.0854
# Validation: [2,    20] loss: 4.295 Accuracy: 0.0938
# Train: [3,    20] loss: 4.326 Accuracy: 0.1375
# Train: [3,    40] loss: 2.641 Accuracy: 0.1156
# Train: [3,    60] loss: 2.068 Accuracy: 0.1083
# Validation: [3,    20] loss: 4.091 Accuracy: 0.1313
# Train: [4,    20] loss: 4.151 Accuracy: 0.1062
# Train: [4,    40] loss: 2.569 Accuracy: 0.0969
# Train: [4,    60] loss: 1.996 Accuracy: 0.1313
# Validation: [4,    20] loss: 4.020 Accuracy: 0.1250
# Train: [5,    20] loss: 3.993 Accuracy: 0.1875
# Train: [5,    40] loss: 2.464 Accuracy: 0.1625
# Train: [5,    60] loss: 1.995 Accuracy: 0.1396
# Validation: [5,    20] loss: 3.878 Accuracy: 0.2188
# Train: [6,    20] loss: 3.910 Accuracy: 0.2250
# Train: [6,    40] loss: 2.440 Accuracy: 0.2125
# Train: [6,    60] loss: 1.925 Accuracy: 0.2125
# Validation: [6,    20] loss: 3.750 Accuracy: 0.2062
# Train: [7,    20] loss: 3.909 Accuracy: 0.1688
# Train: [7,    40] loss: 2.365 Accuracy: 0.1750
# Train: [7,    60] loss: 1.914 Accuracy: 0.1917
# Validation: [7,    20] loss: 3.871 Accuracy: 0.2188
# Train: [8,    20] loss: 3.733 Accuracy: 0.2375
# Train: [8,    40] loss: 2.325 Accuracy: 0.2562
# Train: [8,    60] loss: 1.879 Accuracy: 0.2583
# Validation: [8,    20] loss: 3.522 Accuracy: 0.2500
# Train: [9,    20] loss: 3.607 Accuracy: 0.2625
# Train: [9,    40] loss: 2.271 Accuracy: 0.2687
# Train: [9,    60] loss: 1.831 Accuracy: 0.2771
# Validation: [9,    20] loss: 3.399 Accuracy: 0.3000
# Train: [10,    20] loss: 3.403 Accuracy: 0.2812
# Train: [10,    40] loss: 2.220 Accuracy: 0.2938
# Train: [10,    60] loss: 1.774 Accuracy: 0.3208
# Validation: [10,    20] loss: 3.337 Accuracy: 0.2875
# Train: [11,    20] loss: 3.379 Accuracy: 0.3125
# Train: [11,    40] loss: 2.147 Accuracy: 0.3469
# Train: [11,    60] loss: 1.767 Accuracy: 0.3479
# Validation: [11,    20] loss: 3.355 Accuracy: 0.3438
# Train: [25,    60] loss: 1.474 Accuracy: 0.6000
# Validation: [25,    20] loss: 2.302 Accuracy: 0.5625
# Train: [26,    20] loss: 2.334 Accuracy: 0.6188
# Train: [26,    40] loss: 1.753 Accuracy: 0.5781
# Train: [26,    60] loss: 1.371 Accuracy: 0.6104
# Validation: [26,    20] loss: 2.236 Accuracy: 0.6062
# Train: [27,    20] loss: 2.377 Accuracy: 0.5813
# Train: [27,    40] loss: 1.600 Accuracy: 0.6281
# Train: [27,    60] loss: 1.378 Accuracy: 0.6562
# Validation: [27,    20] loss: 2.190 Accuracy: 0.6438
# Train: [28,    20] loss: 2.142 Accuracy: 0.6500
# Train: [28,    40] loss: 1.659 Accuracy: 0.6062
# Train: [28,    60] loss: 1.408 Accuracy: 0.6312
# Validation: [28,    20] loss: 2.065 Accuracy: 0.6625
# Train: [29,    20] loss: 2.133 Accuracy: 0.6937
# Train: [29,    40] loss: 1.575 Accuracy: 0.6875
# Train: [29,    60] loss: 1.403 Accuracy: 0.6708
# Validation: [29,    20] loss: 2.006 Accuracy: 0.6750
# Train: [30,    20] loss: 2.098 Accuracy: 0.6813
# Train: [30,    40] loss: 1.575 Accuracy: 0.6813
# Train: [30,    60] loss: 1.362 Accuracy: 0.6646
# Validation: [30,    20] loss: 2.020 Accuracy: 0.7125
# Finished Training

# %%
#do some predictions
trainsetLoader = DataLoader(trainset, shuffle=True)
valsetLoader = DataLoader(valset, shuffle=True)

dataiter = iter(valsetLoader)
images, labels, image_name, class_name = dataiter.next()

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', class_name)

images = images.cuda()
output = mobilenet(images)
_, predicted = torch.max(output, 1)

print('Predicted: ', classes[predicted.item()])
# Out:
# GroundTruth:  ('Mechanical Building',)
# Predicted:  Mechanical Building

# %%
loss_fn = nn.CrossEntropyLoss()
alexnet = models.alexnet(pretrained=False)
alexnet.classifier[6] = nn.Linear(4096, 20)
optimizer = optim.SGD(alexnet.parameters(), lr=5e-3, momentum=0.9)
train_model(alexnet, loss_fn, 8, trainset, valset, optimizer, 30)
# Out:
# Train: [1,    20] loss: 4.149 Accuracy: 0.0750
# Train: [1,    40] loss: 2.526 Accuracy: 0.0906
# Train: [1,    60] loss: 2.005 Accuracy: 0.0917
# Validation: [1,    20] loss: 4.069 Accuracy: 0.0938
# Train: [2,    20] loss: 4.036 Accuracy: 0.1250
# Train: [2,    40] loss: 2.485 Accuracy: 0.1219
# Train: [2,    60] loss: 1.995 Accuracy: 0.1187
# Validation: [2,    20] loss: 4.035 Accuracy: 0.0938
# Train: [3,    20] loss: 4.074 Accuracy: 0.0750
# Train: [3,    40] loss: 2.488 Accuracy: 0.0750
# Train: [3,    60] loss: 1.977 Accuracy: 0.0875
# Validation: [3,    20] loss: 4.027 Accuracy: 0.0938
# Train: [4,    20] loss: 4.060 Accuracy: 0.0875
# Train: [4,    40] loss: 2.489 Accuracy: 0.1000
# Train: [4,    60] loss: 1.985 Accuracy: 0.1000
# Validation: [4,    20] loss: 3.986 Accuracy: 0.0938
# Train: [5,    20] loss: 4.015 Accuracy: 0.1000
# Train: [5,    40] loss: 2.495 Accuracy: 0.0938
# Train: [5,    60] loss: 1.964 Accuracy: 0.1042
# Validation: [5,    20] loss: 3.986 Accuracy: 0.0938
# Train: [19,    40] loss: 2.474 Accuracy: 0.0781
# Train: [19,    60] loss: 1.942 Accuracy: 0.0896
# Validation: [19,    20] loss: 3.854 Accuracy: 0.1562
# Train: [20,    20] loss: 3.881 Accuracy: 0.1875
# Train: [20,    40] loss: 2.374 Accuracy: 0.1688
# Train: [20,    60] loss: 1.913 Accuracy: 0.1604
# Validation: [20,    20] loss: 3.777 Accuracy: 0.1562
# Train: [21,    20] loss: 3.616 Accuracy: 0.2250
# Train: [21,    40] loss: 2.360 Accuracy: 0.1875
# Train: [21,    60] loss: 1.879 Accuracy: 0.1833
# Validation: [21,    20] loss: 3.542 Accuracy: 0.2250
# Train: [22,    20] loss: 3.564 Accuracy: 0.2375
# Train: [22,    40] loss: 2.353 Accuracy: 0.2156
# Train: [22,    60] loss: 1.903 Accuracy: 0.2250
# Validation: [22,    20] loss: 3.725 Accuracy: 0.2000
# Train: [23,    20] loss: 3.583 Accuracy: 0.1938
# Train: [23,    40] loss: 2.225 Accuracy: 0.2250
# Train: [23,    60] loss: 1.866 Accuracy: 0.2188
# Validation: [23,    20] loss: 3.595 Accuracy: 0.2250
# Train: [24,    20] loss: 3.599 Accuracy: 0.2188
# Train: [24,    40] loss: 2.183 Accuracy: 0.2281
# Train: [24,    60] loss: 1.855 Accuracy: 0.2208
# Validation: [24,    20] loss: 3.507 Accuracy: 0.2562
# Train: [25,    20] loss: 3.330 Accuracy: 0.2375
# Train: [25,    40] loss: 2.126 Accuracy: 0.2687
# Train: [25,    60] loss: 1.886 Accuracy: 0.2354
# Validation: [25,    20] loss: 3.360 Accuracy: 0.3250
# Train: [26,    20] loss: 3.501 Accuracy: 0.2750
# Train: [26,    40] loss: 2.208 Accuracy: 0.2687
# Train: [26,    60] loss: 1.756 Accuracy: 0.2708
# Validation: [26,    20] loss: 3.330 Accuracy: 0.3125
# Train: [27,    20] loss: 3.327 Accuracy: 0.2938
# Train: [27,    40] loss: 2.217 Accuracy: 0.2750
# Train: [27,    60] loss: 1.694 Accuracy: 0.3042
# Validation: [27,    20] loss: 3.295 Accuracy: 0.3250
# Train: [28,    20] loss: 3.238 Accuracy: 0.3187
# Train: [28,    40] loss: 2.001 Accuracy: 0.3375
# Train: [28,    60] loss: 1.680 Accuracy: 0.3271
# Validation: [28,    20] loss: 3.228 Accuracy: 0.2812
# Train: [29,    20] loss: 3.023 Accuracy: 0.4125
# Train: [29,    40] loss: 2.143 Accuracy: 0.3312
# Train: [29,    60] loss: 1.633 Accuracy: 0.3625
# Validation: [29,    20] loss: 3.141 Accuracy: 0.3750
# Train: [30,    20] loss: 3.036 Accuracy: 0.4000
# Train: [30,    40] loss: 2.028 Accuracy: 0.3906
# Train: [30,    60] loss: 1.683 Accuracy: 0.3833
# Validation: [30,    20] loss: 3.208 Accuracy: 0.2750
# Finished Training

# %%
#do some predictions
trainsetLoader = DataLoader(trainset, shuffle=True)
valsetLoader = DataLoader(valset, shuffle=True)

dataiter = iter(valsetLoader)
images, labels, image_name, class_name = dataiter.next()

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', class_name)

images = images.cuda()
output = mobilenet(images)
_, predicted = torch.max(output, 1)

print('Predicted: ', classes[predicted.item()])
# Out:
# GroundTruth:  ('Physics Building',)
# Predicted:  Physics Building
